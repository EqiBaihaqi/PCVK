# %% [markdown]
# ##Langkah 1
#
# pada code awal, Pada code awal, beberapa library yang akan digunakan adalah : numphy, pandas, cv2, skimage, PIL, matploib

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow #for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# ##Langkah 2
# untuk membaca dan menampilkan image

# %%
#Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/571"]
#Baca dan tampilkan image
#Loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                            #Read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)   #Resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)    #Convert color to RGB
  final_frame = cv.hconcat((image, image_2))        #Concatenate image
  cv2_imshow(final_frame)                           #Show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# ##LANGKAH 3
# pada praktikum ini adalah melihat ukuran file image, dengan cara sebagai
# berikut

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi, " x ", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %% [markdown]
# ##LANGKAH 4
# berikut digunakan untuk mengakses pixel dengan memberikan garis
# horizontal berwarna putih di tengah image

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# #PERTANYAAN

# %% [markdown]
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
#
#     **Jawab:**
#     *   Dapat diakses pada web browser tanpa installasi
#     *   Dapat berkolaborasi dengan mudah dan real time
#     *   Dapat terigentrasi dengan google drive dan github
#     *   Dapat langsung memanggil library untuk bahasa phyton

# %% [markdown]
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan?
# Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
#
#     **Jawab:**
#
#     *   numpy: Library ini digunakan untuk melakukan operasi numerik dan manipulasi array multidimensi
#     *   pandas:  Digunakan untuk manipulasi dan analisis data tabular, seperti membaca dan menulis data dalam berbagai format, menjalankan operasi agregasi, dan melakukan pembersihan data
#     *   cv2 (OpenCV): OpenCV adalah library komputer vision yang sering digunakan untuk memproses gambar dan video.
#     *   google.colab.patches.cv2_imshow: Ini adalah patch khusus untuk Google Colab yang memungkinkan tampilan gambar menggunakan OpenCV pada notebook Colab.
#     *   PIL (Python Imaging Library): PIL adalah library populer untuk manipulasi gambar dalam Python. Digunakan untuk membaca, menulis, dan memanipulasi gambar dalam berbagai format
#     *   skimage.io: Library ini menyediakan fungsi untuk membaca dan menulis gambar dari berbagai format file. Digunakan untuk membaca gambar dari file atau URL.
#
#     Namun library yang dipakai adalah OpenCV dan Skimage

# %% [markdown]
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
#
#     image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
#
#     Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
#
#     **Jawab: **
#
#     Kode program tersebut digunakan untuk mengubah ukuran gambar menggunakan fungsi resize() dari library OpenCV (cv2). Ukuran gambar menghasilkan output mengurangi ukuran gambar menjadi setengah
#
#     Jika kode tersebut tidak dilakukan, maka gambar akan tetap memiliki ukuran asli tanpa perubahan

# %% [markdown]
# 4. Perhatikan potongan kode progam berikut :
#
#     for y in range(lebar);
#
#     image_3[int((tinggi)/2),y] = [255,255,255]
#
#     Apakah kegunaan kode [255,255,255] ? Jelaskan!
#
#     **Jawab:**
#
#     Kode [255, 255, 255] ini mewakili nilai piksel dalam model warna RGB. Sehingga dalam kode tersebut digunakan untuk mewarnai objek dalama variable image_3

# %% [markdown]
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
#
#     **Jawab:**
#
#     Resolusi gambar yang tinggi berarti gambar tersebut memiliki lebih banyak pixel per unit panjang atau lebar. Sedangkan gambar dengan resolusi rendah memiliki jumlah pixel yang lebih sedikit per unit panjang atau lebar

# %% [markdown]
# #Tugas

# %% [markdown]
# Buat garis vertikal

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_4 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for x in range (tinggi):
  image_4[x, int(lebar/2)] = [255,255,255]
final_frame = cv.hconcat((image_2, image_4))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# garis menyilang diagonal pada image keluaran

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis menyilang diagonal image
cv.line(image_3, (0,0), (lebar, tinggi), (255,255,255))
cv.line(image_3, (400,0), (0, tinggi), (255,255,255))

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# Buat garis horisontal berwarna putih dibagian tengah gambar dengan panjang
# tertentu

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

cv.line(image_3, (100,100), (200, 100), (255,255,255))

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat dalam
# gambar

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat kotak di gambar
kotak_x = 100  # Titik x kotak
kotak_y = 150  # Titik y kotak
kotak_lebar = 200  # Lebar kotak
kotak_tinggi = 90  # Tinggi kotak

# Membuat kotak dengan piksel warna putih
for y in range(kotak_y, kotak_y + kotak_tinggi):
    for x in range(kotak_x, kotak_x + kotak_lebar):
        image_3[y, x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# ##Tugas Kelompok 12

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import matplotlib.pyplot as plt

# Path file gambar
image_path = '/content/drive/MyDrive/PCVK SMT 5/Modul 1/Salinan KTP.jpeg'

# Baca gambar menggunakan OpenCV
image_8 = cv2.imread(image_path)

# Ubah warna gambar dari BGR ke RGB
image_8 = cv2.cvtColor(image_8, cv2.COLOR_BGR2RGB)

# Tampilkan gambar menggunakan Matplotlib
plt.imshow(image_8)
plt.axis('off')
plt.show()

# %%
# Mengubah warna pada bagian tempat tanggal lahir
for y in range(190, 450):  # lebar
    for x in range(140, 160):  # panjang
        image_8[x, y] = 253, 215, 3 # warna

# Mengubah warna pada bagian jenis kelamin
for y in range(190, 300):  # lebar
    for x in range(165, 185):  # panjang
        image_8[x, y] = [255, 0, 0] # warna

# Tampilkan gambar dengan kotak warna yang telah dimodifikasi
plt.imshow(image_8)
plt.axis('off')
plt.show()
